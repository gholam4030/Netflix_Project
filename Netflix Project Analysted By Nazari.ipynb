# %%
#NETFLIX Project Analysted By Gholam Hosin Nazari

# %%
import pandas as pd

# %%
data=pd.read_csv('filea.csv')

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
data.tail(2)
# Out:
#      Show_Id Category                                    Title  Director  \
# 7787   s7786  TV Show                    Zumbo's Just Desserts       NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn
#
#                             Cast                                Country  \
# 7787  Adriano Zumbo, Rachel Khoo                              Australia
# 7788                         NaN  United Kingdom, Canada, United States
#
#           Release_Date Rating  Duration                                Type  \
# 7787  October 31, 2020  TV-PG  1 Season  International TV Shows, Reality TV
# 7788     March 1, 2020  TV-MA    90 min     Documentaries, Music & Musicals
#
#                                             Description
# 7787  Dessert wizard Adriano Zumbo looks for the nex...
# 7788  This documentary delves into the mystique behi...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.size
# Out:
# 85679

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
#Find the duplicated record and remove it.

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
#romove the duplicates record
data.drop_duplicates(inplace=True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data.shape
# Out:
# (7787, 11)

# %%
#Is there null value? Show with heat-map

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#Q1:For 'House of card' what is the show id and who is the direct of this show?

# %%
data.head()

# %%
data[data['Title'].isin(['House of Cards'])]

# %%
data[data['Title'].str.contains('House of Cards')]

# %%
#Q2: In which year highest number of the TV shows & movies were released? Show the Bar graph.

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data['Date_N'] = pd.to_datetime(data['Release_Date'],format='%B %d, %Y', errors='coerce')

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# Date_N
# 2019.0    2136
# 2020.0    2008
# 2018.0    1661
# 2017.0    1201
# 2016.0     432
# 2021.0     117
# 2015.0      79
# 2014.0      24
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date_N'>

# %%
#How many Movies & TV Shows are in the dataset? Show with Bar Graph.

# %%
data.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data.groupby(['Category']).Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
data['Category'] = pd.factorize(data.Category)[0]

# %%
data.head(2)
# Out:
#   Show_Id  Category  Title           Director  \
# 0      s1         0     3%                NaN
# 1      s2         1  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data.groupby(['Category']).Category.count().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
#Q4.Show all the movies that were released in year 2000

# %%
data.head(2)
# Out:
#   Show_Id  Category  Title           Director  \
# 0      s1         0     3%                NaN
# 1      s2         1  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data['Year']=data['Date_N'].dt.year

# %%
data.head(2)
# Out:
#   Show_Id  Category  Title           Director  \
# 0      s1         0     3%                NaN
# 1      s2         1  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
#Filtering
data[(data['Category']==1) & (data['Year']==2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
#Show only the titles of all TV Shows that were Released in India only.

# %%
data.head(2)
# Out:
#   Show_Id  Category  Title           Director  \
# 0      s1         0     3%                NaN
# 1      s2         1  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[(data['Category']==0) & (data['Country']=='India')]['Title']

# %%
#Show top 10 directors, who gave the highest number of TV shows & movies to Netflix?

# %%
data['Director'].value_counts().head(10)

# %%
#Q8.Show all the records, where "category is movies and type is comedies"or " country is united kingdom".

# %%
data[(data['Category']==1)&(data['Type']=='Comedies')|(data['Country']=='United Kingdom')]

# %%
#Q8. In how many movies/shows, Tom Cruise was cast?

# %%
data.head(2)

# %%
data[data['Cast']=='Tom Cruise']

# %%
data_new=data.dropna()

# %%
data_new.head(2)

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]

# %%
#Q9. What are the different rating defined by Netflix?

# %%
data.head(2)

# %%
data['Rating'].nunique()

# %%
data['Rating'].unique()

# %%
#Q9.1. How many Movies got the 'TV-!4'rating in Canada?

# %%
data[(data['Category']==1)&(data['Rating']=='TV-14')].shape

# %%
data[(data['Category']==1)&(data['Rating']=='TV-14')&(data['Country']=='Canada')]
# Out:
#      Show_Id  Category                                        Title  \
# 30       s31         1                             #cats_the_mewvie
# 34       s35         1                                        #Roxy
# 608     s609         1                               At First Light
# 1506   s1507         1                   Counterfeiting in Suburbia
# 3713   s3714         1                            Long Time Running
# 3956   s3957         1  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336         1                   Sadie's Last Days on Earth
# 5393   s5393         1                                   Sardaar ji
# 6062   s6062         1                  The Accountant of Auschwitz
# 7025   s7024         1                         The Wrong Babysitter
# 7041   s7040         1               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %%
#Q.9.2.How many TV show got the 'R' rating after year 2018?

# %%
data.head(2)
# Out:
#   Show_Id  Category  Title           Director  \
# 0      s1         0     3%                NaN
# 1      s2         1  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[(data['Category']==0)&(data['Rating']=='R')]
# Out:
#      Show_Id  Category                                Title  \
# 4497   s4498         0                                Nobel
# 6437   s6436         0  The Hateful Eight: Extended Version
#
#                Director                                               Cast  \
# 4497                NaN  Aksel Hennie, Tuva Novotny, Anders Danielsen L...
# 6437  Quentin Tarantino  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...
#
#      Country       Release_Date Rating  Duration  \
# 4497  Norway  December 10, 2016      R  1 Season
# 6437     NaN     April 25, 2019      R  1 Season
#
#                                                  Type  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6437                                         TV Shows
#
#                                             Description     Date_N    Year
# 4497  A series of incidents in Afghanistan set compl... 2016-12-10  2016.0
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
data[(data['Category']==0)&(data['Rating']=='R')&(data['Year']>2018)]
# Out:
#      Show_Id  Category                                Title  \
# 6437   s6436         0  The Hateful Eight: Extended Version
#
#                Director                                               Cast  \
# 6437  Quentin Tarantino  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...
#
#      Country    Release_Date Rating  Duration      Type  \
# 6437     NaN  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description     Date_N    Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
#Q.10. What is the maximum duration of a Movie/Show on Netflix?

# %%
data.head(2)
# Out:
#   Show_Id  Category  Title           Director  \
# 0      s1         0     3%                NaN
# 1      s2         1  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data.Duration.dtypes
# Out:
# dtype('O')

# %%
data.head(2)
# Out:
#   Show_Id  Category  Title           Director  \
# 0      s1         0     3%                NaN
# 1      s2         1  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
data[['Minutes','Unit']]=data['Duration'].str.split(' ',expand=True)

# %%
data.head(2)
# Out:
#   Show_Id  Category  Title           Director  \
# 0      s1         0     3%                NaN
# 1      s2         1  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
data['Minutes'].max()
# Out:
# '99'

# %%
data['Minutes'].min()
# Out:
# '1'

# %%
data['Minutes'].mean()
# Out:
# inf

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                 int64
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# Year                   float64
# Minutes                 object
# Unit                    object
# dtype: object

# %%
#Q.11. Which individual country has the highest No.of TV Shows?

# %%
data.head(2)
# Out:
#   Show_Id  Category  Title           Director  \
# 0      s1         0     3%                NaN
# 1      s2         1  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
data_tvshow=data[data['Category']==0]

# %%
data_tvshow.head(2)
# Out:
#   Show_Id  Category Title     Director  \
# 0      s1         0    3%          NaN
# 5      s6         0    46  Serdar Akar
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017.0
#
#   Minutes     Unit
# 0       4  Seasons
# 5       1   Season

# %%
data_tvshow.Country.value_counts()
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
data_tvshow.Country.value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %%
#Q.12. How can we sort the dataset by year?

# %%
data.head(2)
# Out:
#   Show_Id  Category  Title           Director  \
# 0      s1         0     3%                NaN
# 1      s2         1  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
data.sort_values(by='Year')
# Out:
#      Show_Id  Category                        Title              Director  \
# 7115   s7114         1         To and From New York  Sorin Dan Mihalcescu
# 1765   s1766         0              Dinner for Five                   NaN
# 3248   s3249         1      Just Another Love Story          Ole Bornedal
# 5766   s5766         1                     Splatter             Joe Dante
# 3840   s3841         1  Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...       ...                          ...                   ...
# 6952   s6951         0                   The Tudors                   NaN
# 6998   s6997         0                The West Wing                   NaN
# 7448   s7447         0                      Vroomiz                   NaN
# 7524   s7523         0   Weird Wonders of the World                   NaN
# 7655   s7654         0            Women Behind Bars                   NaN
#
#                                                    Cast  \
# ...

# %%
data.sort_values(by='Year',ascending=False)
# Out:
#      Show_Id  Category                                              Title  \
# 5564   s5564         1                                    Sherlock Holmes
# 5919   s5919         1                                          Surf's Up
# 980     s981         0                                       Bling Empire
# 1355   s1356         1  Chris Rock Total Blackout: The Tamborine Exten...
# 5955   s5955         1                                   Taare Zameen Par
# ...      ...       ...                                                ...
# 6952   s6951         0                                         The Tudors
# 6998   s6997         0                                      The West Wing
# 7448   s7447         0                                            Vroomiz
# 7524   s7523         0                         Weird Wonders of the World
# 7655   s7654         0                                  Women Behind Bars
#
#                      Director  \
# 5564              Guy Ritchie
# ...

# %%
#Q.13. Find all the instance where:
 #   Category is 'Movie' and 'Type is 'Dramas'
  #  or Category is 'TV Show' & Type is 'Kids TV'

# %%
data.head(2)
# Out:
#   Show_Id  Category  Title           Director  \
# 0      s1         0     3%                NaN
# 1      s2         1  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
data[(data['Category']==1)&(data['Type']=='Dramas')].head(2)
# Out:
#   Show_Id  Category Title        Director  \
# 4      s5         1    21  Robert Luketic
# 7      s8         1   187  Kevin Reynolds
#
#                                                 Cast        Country  \
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 7  Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
#
#        Release_Date Rating Duration    Type  \
# 4   January 1, 2020  PG-13  123 min  Dramas
# 7  November 1, 2019      R  119 min  Dramas
#
#                                          Description     Date_N    Year  \
# 4  A brilliant group of students become card-coun... 2020-01-01  2020.0
# 7  After one of his high school students attacks ... 2019-11-01  2019.0
#
#   Minutes Unit
# 4     123  min
# 7     119  min

# %%
data[(data['Category']==0)&(data['Type']=="Kids' TV")].head(2)
# Out:
#     Show_Id  Category         Title     Director  \
# 111    s112         0       44 Cats          NaN
# 276    s277         0  Abby Hatcher  Kyran Kelly
#
#                                                   Cast                Country  \
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
#
#         Release_Date Rating   Duration      Type  \
# 111  October 1, 2020  TV-Y7  2 Seasons  Kids' TV
# 276     July 1, 2020   TV-Y   1 Season  Kids' TV
#
#                                            Description     Date_N    Year  \
# 111  Paw-esome tales abound when singing furry frie... 2020-10-01  2020.0
# 276  A big-hearted girl helps her Fuzzly friends wh... 2020-07-01  2020.0
#
#     Minutes     Unit
# 111       2  Seasons
# 276       1   Season

# %%
data[(data['Category']==1)&(data['Type']=='Dramas') | (data['Category']==0)&(data['Type']=="Kids' TV")]
# Out:
#      Show_Id  Category                       Title        Director  \
# 4         s5         1                          21  Robert Luketic
# 7         s8         1                         187  Kevin Reynolds
# 111     s112         0                     44 Cats             NaN
# 170     s171         1                A Family Man   Mark Williams
# 232     s233         1  A Stoning in Fulham County   Larry Elikann
# ...      ...       ...                         ...             ...
# 7668   s7667         0               World of Winx  Iginio Straffi
# 7717   s7716         0                        Yoko             NaN
# 7719   s7718         0                         YOM             NaN
# 7758   s7757         0                          Z4             NaN
# 7761   s7760         0                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
#Thank you.
